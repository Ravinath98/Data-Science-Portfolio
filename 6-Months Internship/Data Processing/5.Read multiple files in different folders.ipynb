# %%
#import libraries...
import pandas as pd
import glob

# %%
folders=['july1','july2'] #list of folders...
for folder in folders: #iterate over folders
    path=r"E:\Desktop\Datasets\forcast_july"
    path_folder=path+"\\"+folder
    print(path_folder)
    filenames_xls = glob.glob(path_folder + "\*.xls") #xls extensions..
    print(filenames_xls)
    for file in filenames_xls: #iterate over files
        print(file)
        df=pd.read_excel(file)
        print(df.head())
        print('-------------------------------------------------------------------------------------------------')
# Out:
# E:\Desktop\Datasets\forcast_july\july1
# ['E:\\Desktop\\Datasets\\forcast_july\\july1\\july1.xls']
# E:\Desktop\Datasets\forcast_july\july1\july1.xls
#   3.    Day Ahead Economic Dispatch for next day in MW           Unnamed: 1  \
# 0                                               Date    2020-07-01 00:00:00
# 1                                                NaN               00:00:00
# 2                                           WPS                           0
# 3                                          Cany                           0
# 4                                        Olax                            10
#
#   Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1   00:30:00   01:00:00   01:30:00   02:00:00   02:30:00   03:00:00
# 2          0          0          0          0          0          0
# 3          0          0          0          0          0          0
# ...

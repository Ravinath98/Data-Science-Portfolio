# %%
#import libraries...
import pandas as pd
import glob

# %%
path_folder=r"E:\Desktop\Datasets\forcast_july"
filenames_xls = glob.glob(path_folder + "\*.xls") #xls extensions..
print(filenames_xls)
for file in filenames_xls: #iterate over files
    print(file)
    df=pd.read_excel(file)
    print(df.head())
    print('-------------------------------------------------------------------------------------------------')
# Out:
# ['E:\\Desktop\\Datasets\\forcast_july\\july10.xls', 'E:\\Desktop\\Datasets\\forcast_july\\july11.xls', 'E:\\Desktop\\Datasets\\forcast_july\\july12.xls', 'E:\\Desktop\\Datasets\\forcast_july\\july13.xls', 'E:\\Desktop\\Datasets\\forcast_july\\july14.xls', 'E:\\Desktop\\Datasets\\forcast_july\\july15.xls', 'E:\\Desktop\\Datasets\\forcast_july\\july16.xls', 'E:\\Desktop\\Datasets\\forcast_july\\july17.xls', 'E:\\Desktop\\Datasets\\forcast_july\\july18.xls', 'E:\\Desktop\\Datasets\\forcast_july\\july19.xls', 'E:\\Desktop\\Datasets\\forcast_july\\july20.xls', 'E:\\Desktop\\Datasets\\forcast_july\\july21.xls', 'E:\\Desktop\\Datasets\\forcast_july\\july22.xls', 'E:\\Desktop\\Datasets\\forcast_july\\july23.xls', 'E:\\Desktop\\Datasets\\forcast_july\\july24.xls', 'E:\\Desktop\\Datasets\\forcast_july\\july25.xls', 'E:\\Desktop\\Datasets\\forcast_july\\july26.xls', 'E:\\Desktop\\Datasets\\forcast_july\\july27.xls', 'E:\\Desktop\\Datasets\\forcast_july\\july28.xls', 'E:\\Desktop\\Datasets\\forc
# ...
